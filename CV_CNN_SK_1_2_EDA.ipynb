# %% [markdown]
# # CNN CLASSIFICATION - SKIN CANCER

# %% [markdown]
# ## 1. Import Modules and Configuration Settings

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ## 2. Load MetaData File

# %%
df = pd.read_csv('ham_meta.csv')
print(f'Shape of the Dataset: {df.shape}')

df.sample(5)
# Out:
# Shape of the Dataset: (10015, 7)
#         lesion_id      image_id     dx    dx_type   age     sex  \
# 3660  HAM_0005417  ISIC_0027966    bcc      histo  65.0    male
# 5399  HAM_0004936  ISIC_0029705    mel      histo  80.0    male
# 6296  HAM_0007555  ISIC_0030602  akiec      histo  60.0    male
# 4960  HAM_0004750  ISIC_0029266     nv  follow_up  45.0  female
# 3891  HAM_0004711  ISIC_0028197    bcc      histo  85.0    male
#
#          localization
# 3660  upper extremity
# 5399            chest
# 6296  upper extremity
# 4960            trunk
# 3891  upper extremity

# %% [markdown]
# ## 3. Analysis

# %%
df.isna().sum()
# Out:
# lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age             57
# sex              0
# localization     0
# dtype: int64

# %%
print(df['dx'].value_counts())
sb.catplot(data=df, x='dx', kind='count')
# Out:
# dx
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: count, dtype: int64

# %%
print(df['dx_type'].value_counts())
sb.catplot(data=df, x='dx_type', kind='count')
# Out:
# dx_type
# histo        5340
# follow_up    3704
# consensus     902
# confocal       69
# Name: count, dtype: int64

# %%
print(df['sex'].value_counts())
sb.catplot(data=df, x='sex', kind='count')
# Out:
# sex
# male       5406
# female     4552
# unknown      57
# Name: count, dtype: int64

# %%
print(df['localization'].value_counts())
sb.catplot(data=df, y='localization', kind='count')
# Out:
# localization
# back               2192
# lower extremity    2077
# trunk              1404
# upper extremity    1118
# abdomen            1022
# face                745
# chest               407
# foot                319
# unknown             234
# neck                168
# scalp               128
# hand                 90
# ear                  56
# genital              48
# acral                 7
# Name: count, dtype: int64

# %%
sb.kdeplot(data=df, x='age')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
df['age'].skew()
# Out:
# -0.16680239035840483

# %% [markdown]
# ## 4. Conclusions

# %% [markdown]
# #### 1. Feature 'age' has 57 missing values for the patients.
# #### 2. For feature 'dx', class label 'nv' is the dominating category with 6705 entries in the dataset.
# #### 3. Feature 'dx_type' has 'histo' as the most frequent method of detecting cancer with 5340 records in the dataset.
# #### 4. Feature 'sex' has 3 categories as ['male', 'female', 'unknown'], where 'male' has occured 5406 times in the dataset.
# #### 5. More number of cases (2192) are present for 'back' category of 'localization' feature.
# #### 6. Distribution for the age of the patients is slightly left skewed (negatively skewed) with a value of -0.1668.
